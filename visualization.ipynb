# %%
import non_gaussian_surfaces as seb

# %%
surface = seb.SAimage_fft_2(N=100, rms=1, skewness=5, kurtosis=-7, corlength_x=7, corlength_y=9, alpha=0.9,
                  threshold=3.0, non_Gauss=False, corr=False)

# %%
surface
# Out:
# array([[1.14915343, 1.22034694, 1.25206326, ..., 1.09249969, 1.09895367,
#         1.09323008],
#        [1.32298689, 1.36733548, 1.40394185, ..., 1.21707348, 1.24350713,
#         1.30050947],
#        [1.5865828 , 1.63445408, 1.70104527, ..., 1.40369768, 1.50804998,
#         1.55493328],
#        ...,
#        [0.92304969, 1.08402961, 1.14606947, ..., 0.38518849, 0.37974238,
#         0.69032966],
#        [0.86514345, 1.03275023, 1.16211443, ..., 0.17812216, 0.35237212,
#         0.74279637],
#        [0.91549599, 1.04987864, 1.18798085, ..., 0.74334164, 0.75838761,
#         0.79492682]])
