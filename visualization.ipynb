# %%
import non_gaussian_surfaces as seb

# %%
surface = seb.SAimage_fft_2(N=100, rms=8, skewness=6, kurtosis=-2, corlength_x=4, corlength_y=2, alpha=0.7,
                  threshold=3.0, non_Gauss=True, corr=False)
# Out:
# JohnsonSU params: gamma=-1.3525694997209639, delta=1.0112667815261631, xi=-6.211615367945023, lambda=1.0

# %%
surface
# Out:
# array([[79.05077008, 78.50187462, 78.42129365, ..., 79.87639333,
#         74.79375364, 74.284903  ],
#        [82.26282549, 81.59917297, 77.0038801 , ..., 82.65595618,
#         81.03051782, 80.65367266],
#        [83.69441174, 81.63923611, 78.34170173, ..., 83.52461991,
#         82.11082898, 82.19919314],
#        ...,
#        [72.21567858, 62.11318711, 53.40376315, ..., 76.11917539,
#         58.79265398, 70.88118651],
#        [75.65602885, 67.78824414, 68.72386638, ..., 78.62494475,
#         58.08320419, 73.23236624],
#        [73.86187887, 70.08519572, 76.14092294, ..., 80.91088624,
#         63.34374705, 72.92215163]])
